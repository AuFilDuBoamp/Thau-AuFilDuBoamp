# %% [markdown]
# <style>
# .afdb-publication { font-family: "Roboto", Arial, sans-serif; color: #263238; line-height: 1.6; }
# .afdb-publication h1, .afdb-publication h2 { color: #51318f; }
# .afdb-kicker { color: #6b7280; font-size: 0.95rem; letter-spacing: 0.04em; text-transform: uppercase; }
# .afdb-card { border-left: 5px solid #7c5ac7; background: #f7f4fc; padding: 1rem 1.2rem; margin: 1.2rem 0; }
# .afdb-nav { border-top: 1px solid #ddd6ef; margin-top: 2rem; padding-top: 1rem; }
# </style>
#
# <div class="afdb-publication">
#
# <p class="afdb-kicker">Thau AuFilDuBoamp — Radiographie en préparation</p>
#
# # SOCIETE PUBLIQUE LOCALE BASSIN DE THAU — Gardiennage de parcs de stationnement
#
# <div class="afdb-card">
#
# **IDWEB BOAMP :** 26-90507
# **Article SPIP :** 8
# **SIREN :** 815013487
# **Statut de la publication :** EN PRÉPARATION
#
# </div>
#
# Le titre éditorial et le contenu détaillé de cette radiographie seront construits à partir des sources établies. Aucun contenu absent ne sera complété par supposition.
#
# <div class="afdb-nav">
#
# [← Publication précédente](radiographie_26-90505.ipynb) · [Toutes les radiographies](00_ACCUEIL.ipynb) · [Publication suivante →](radiographie_26-90441.ipynb)
#
# [Thau AuFilDuBoamp](https://www.aufilduboamp.com/thau-aufilduboamp) · [Rubrique 144 — référence stable](https://www.aufilduboamp.com/rubrique144)
#
# </div>
#
# </div>
