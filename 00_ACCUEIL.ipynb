# %% [markdown]
# <style>
# .afdb-publication { font-family: "Roboto", Arial, sans-serif; color: #263238; line-height: 1.6; }
# .afdb-publication h1, .afdb-publication h2 { color: #51318f; }
# .afdb-kicker { color: #6b7280; font-size: 0.95rem; letter-spacing: 0.04em; text-transform: uppercase; }
# .afdb-card { border-left: 5px solid #7c5ac7; background: #f7f4fc; padding: 1rem 1.2rem; margin: 1.2rem 0; }
# .afdb-nav { border-top: 1px solid #ddd6ef; margin-top: 2rem; padding-top: 1rem; }
# </style>
#
# <div class="afdb-publication">
#
# <p class="afdb-kicker">Proof of concept éditorial</p>
#
# # Thau AuFilDuBoamp
#
# **Focus sur une sélection de marchés publics en cours sur le territoire de Sète Agglopôle Méditerranée, repérés à partir des avis publiés au BOAMP**
#
# <div class="afdb-card">
# Cette première structure présente les douze radiographies en préparation. Les titres éditoriaux et les contenus détaillés seront élaborés progressivement à partir des sources établies.
# </div>
#
# ## Les radiographies
#
# 1. [26-86396 — Ville de Mèze — Prestation de lutte intégrée contre les nuisibles](radiographie_26-86396.ipynb)
# 2. [26-83178 — Sète Agglopôle Méditerranée — Location de véhicules de collecte des déchets](radiographie_26-83178.ipynb)
# 3. [26-79835 — Sète Agglopôle Méditerranée — Fourniture de colonnes aériennes pour la collecte des déchets](radiographie_26-79835.ipynb)
# 4. [26-67880 — Sète Agglopôle Méditerranée — Traitement et valorisation des déchets conchylicoles](radiographie_26-67880.ipynb)
# 5. [26-62858 — Ville de Sète — Révision générale du Plan local d’urbanisme](radiographie_26-62858.ipynb)
# 6. [25-85828 — Ville de Balaruc-les-Bains — Fourniture de véhicules neufs ou d’occasion](radiographie_25-85828.ipynb)
# 7. [26-70532 — Ville de Sète — Tonte des gazons et entretien des espaces plantés](radiographie_26-70532.ipynb)
# 8. [26-73820 — Commune de Bouzigues — Prestations de services d’assurance](radiographie_26-73820.ipynb)
# 9. [26-74518 — Ville de Balaruc-les-Bains — Requalification du quai des Ondines et de la jetée du Port Centre](radiographie_26-74518.ipynb)
# 10. [26-74720 — Ville de Balaruc-les-Bains — Réhabilitation et végétalisation du Théâtre de Verdure](radiographie_26-74720.ipynb)
# 11. [26-76746 — Sète Agglopôle Méditerranée — Conseil et mise en œuvre du dialogue citoyen](radiographie_26-76746.ipynb)
# 12. [26-88370 — COMMUNE DE SETE — Souscription de contrats d'assurance](radiographie_26-88370.ipynb)
#
# 13. [26-90551 — CA SETE AGGLOPOLE MEDITERRANEE — Maîtrise d’œuvre Pôle d’échange multimodal](radiographie_26-90551.ipynb)
# 14. [26-90505 — ETABLISSEMENT PUBLIC REGIONAL PORT SUD DE FRANCE — Assurance](radiographie_26-90505.ipynb)
# 15. [26-90507 — SOCIETE PUBLIQUE LOCALE BASSIN DE THAU — Gardiennage de parcs de stationnement](radiographie_26-90507.ipynb)
# 16. [26-90441 — SOCIETE PUBLIQUE LOCALE BASSIN DE THAU — Nettoyage de locaux (parkings)](radiographie_26-90441.ipynb)
# 17. [26-90506 — SOCIETE PUBLIQUE LOCALE BASSIN DE THAU — Télégestion des parcs de stationnement](radiographie_26-90506.ipynb)
# 18. [26-91329 — COMMUNE DE MEZE — Fourniture d'équipements numériques et services d'assistance et de maintenance](radiographie_26-91329.ipynb)\n
# ## Accès territorial
#
# - [Thau AuFilDuBoamp](https://www.aufilduboamp.com/thau-aufilduboamp)
# - [Rubrique 144 — référence stable](https://www.aufilduboamp.com/rubrique144)
#
# </div>
